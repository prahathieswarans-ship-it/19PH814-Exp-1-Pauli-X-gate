# %%
# !pip install qiskit[visualization]
# !pip install qiskit-aer
# !pip install qiskit-ibm-runtime
# !pip install qiskit-Aer
# !pip install matplotlib
# !pip install numpy
# Out:
# Collecting qiskit[visualization]
#   Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (2.0.2)
# Requirement already satisfied: scipy>=1.14 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (1.16.3)
# Collecting rustworkx>=0.15.0 (from qiskit[visualization])
#   Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit[visualization])
#   Downloading stevedore-5.9.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (4.16.0)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (3.10.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (4.0.1)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (11.3.0)
# Collecting pylatexenc>=1.4 (from qiskit[visualization])
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (0.13.2)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn>=0.9.0->qiskit[visualization]) (2.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->qiskit[visualization]) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->qiskit[visualization]) (1.17.0)
# Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 27.0 MB/s eta 0:00:00
# Downloading stevedore-5.9.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.1 MB/s eta 0:00:00
# Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 78.2 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=00212cf146b5e0f9f032b1d5719bea17d91ce694229c9eec9cfa3f39cef1af34
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, stevedore, rustworkx, qiskit
# Successfully installed pylatexenc-2.10 qiskit-2.5.0 rustworkx-0.18.0 stevedore-5.9.0
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.5.0)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (1.16.3)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.18.0)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (5.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (4.16.0)
# Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 85.1 MB/s eta 0:00:00
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.17.2
# Collecting qiskit-ibm-runtime
#   Downloading qiskit_ibm_runtime-0.48.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.32.4)
# Collecting requests-ntlm>=1.1.0 (from qiskit-ibm-runtime)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.0.2)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (1.16.3)
# Requirement already satisfied: urllib3>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Collecting ibm-platform-services>=0.61.1 (from qiskit-ibm-runtime)
#   Downloading ibm_platform_services-0.76.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting ibm-quantum-schemas<1,>=0.9.20260612 (from qiskit-ibm-runtime)
#   Downloading ibm_quantum_schemas-0.9.20260612-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pydantic>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.13.4)
# Requirement already satisfied: qiskit>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.5.0)
# Collecting pybase64>=1.4.0 (from qiskit-ibm-runtime)
#   Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Collecting samplomatic>=0.18.0 (from qiskit-ibm-runtime)
#   Downloading samplomatic-0.20.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.4 (from ibm-platform-services>=0.61.1->qiskit-ibm-runtime)
#   Downloading ibm_cloud_sdk_core-3.26.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->qiskit-ibm-runtime) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->qiskit-ibm-runtime) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.9.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.3.0->qiskit-ibm-runtime) (0.18.0)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.3.0->qiskit-ibm-runtime) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.3.0->qiskit-ibm-runtime) (5.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit-ibm-runtime) (2026.6.17)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (49.0.0)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime)
#   Downloading pyspnego-0.12.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from samplomatic>=0.18.0->qiskit-ibm-runtime) (3.11.9)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.1.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.61.1->qiskit-ibm-runtime) (2.13.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (3.0)
# Downloading qiskit_ibm_runtime-0.48.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 30.1 MB/s eta 0:00:00
# Downloading ibm_platform_services-0.76.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.4/400.4 kB 29.2 MB/s eta 0:00:00
# Downloading ibm_quantum_schemas-0.9.20260612-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.3/111.3 kB 9.7 MB/s eta 0:00:00
# Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.6 MB/s eta 0:00:00
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading samplomatic-0.20.0-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.2/224.2 kB 19.7 MB/s eta 0:00:00
# Downloading ibm_cloud_sdk_core-3.26.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 kB 6.7 MB/s eta 0:00:00
# Downloading pyspnego-0.12.1-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: pybase64, ibm_cloud_sdk_core, samplomatic, pyspnego, ibm-platform-services, requests-ntlm, ibm-quantum-schemas, qiskit-ibm-runtime
# Successfully installed ibm-platform-services-0.76.0 ibm-quantum-schemas-0.9.20260612 ibm_cloud_sdk_core-3.26.0 pybase64-1.4.3 pyspnego-0.12.1 qiskit-ibm-runtime-0.48.0 requests-ntlm-1.3.0 samplomatic-0.20.0
# Requirement already satisfied: qiskit-Aer in /usr/local/lib/python3.12/dist-packages (0.17.2)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (2.5.0)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (1.16.3)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-Aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (0.18.0)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (5.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (4.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
import qiskit

print(f"Qiskit version: {qiskit.__version__}")
# Out:
# Qiskit version: 2.5.0

# %%
import qiskit_aer
print(qiskit_aer.__version__)
# Out:
# 0.17.2

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
import matplotlib.pyplot as plt
import numpy as np
# Create a quantum circuit with one qubit
qc = QuantumCircuit(2)
qc.x(0)
#qc.tdg(0)
#qc.sdg(0)
#qc.tdg(0)
#qc.x(1)
#qc.x(0)
#qc.x(1)
#qc.y(0)
#qc.y(1)
#qc.x(0)
#qc.x(1)
#qc.x(0)
# Initial statevector
state1 = Statevector.from_instruction(qc)
print("Initial quantum statevector:")
#print(state1.data)
#!pip install numpy
from qiskit.circuit.instruction import numpy
#import numpy as np
print(np.round(state1.data, 10))
#print(state2.data)
print ("Probability Values")
state1.probabilities()
# Out:
# Initial quantum statevector:
# [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
# Probability Values
# array([0., 1., 0., 0.])

# %%
# Plot Bloch sphere representation
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(state1)
plt.show()

# %%
from IPython.display import display
display(qc.draw(output='mpl'))
print("Input")
# Out:
# Input

# %%
#from qiskit import QuantumCircuit
#from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram
from IPython.display import display

# Simulate the state
state = Statevector.from_instruction(qc)

# Sample measurement results
counts = state.sample_counts(shots=1000)

# Display the histogram
display(plot_histogram(counts))

# %%
#Print Applying Gate
#qc.x(0)
qc.h(0)
qc.x(0)
qc.h(0)
qc.h(1)
qc.x(1)
qc.h(1)

# %%
from IPython.display import display
display(qc.draw(output='mpl'))
print("Input")
# Out:
# Input

# %%
# !pip install numpy
from qiskit.circuit.instruction import numpy
import numpy as np
state2 = Statevector.from_instruction(qc)
print("Final quantum statevector:")
print(np.round(state2.data, 10))
#print(state2.data)
state.probabilities()
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Final quantum statevector:
# [ 0.+0.j -1.+0.j  0.+0.j -0.+0.j]
# array([0., 1., 0., 0.])

# %%
#from qiskit import QuantumCircuit
#from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram
from IPython.display import display

# Simulate the state
state = Statevector.from_instruction(qc)

# Sample measurement results
counts = state.sample_counts(shots=1000)

# Display the histogram
display(plot_histogram(counts))
